# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhannah3/cis198first/blob/main/CIS198_First_lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Colab Notes
#
# * Colab uses interactive pythom
# noteboooks (.ipynb files).
# * A notebook is made up of a vertical stack of cells.
# * There are two cell types:
#   1. code - python
#   2. text - raw text, markdown or html
#
#   *markdown* - is a simple "markup language" that allows you to do formatting, but is still readable in its raw text form.
# ### examples of markdown
# *bold text*.
# **italic text**
#
# [The best university on earth](http://niagara.edu)

# %%
# This is a python comment
# code comments get ignored when the program is run
print('Hello world')
# Out:
# Hello world
