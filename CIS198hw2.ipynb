# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhannah3/cis198first/blob/main/CIS198hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a function in python always has a set of paranthesis following the function name. In the parenthesis put your function inputs aka parameter.

# %%
print("hello world")
